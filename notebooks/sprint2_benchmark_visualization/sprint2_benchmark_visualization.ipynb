# %% [markdown]
# # Sprint 2 Benchmark Visualization
#
# This notebook is an exploratory view over the source-of-truth plotting script in `src.baselines.plot_benchmarks`.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
while repo_root != repo_root.parent and not (repo_root / "src").exists():
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

repo_root

# %%
from IPython.display import Image, display

from src.baselines.plot_benchmarks import (
    DEFAULT_CSV,
    DEFAULT_OUTPUT_DIR,
    generate_charts,
    read_benchmark_csv,
    summarize_benchmarks,
)

csv_path = DEFAULT_CSV
output_dir = DEFAULT_OUTPUT_DIR
csv_path, output_dir

# %%
df = read_benchmark_csv(csv_path)
summary = summarize_benchmarks(df)
summary

# %%
outputs = generate_charts(summary, output_dir=output_dir, formats=("png",))
outputs

# %%
for stem, paths in outputs.items():
    print(stem)
    display(Image(filename=str(paths[0])))
